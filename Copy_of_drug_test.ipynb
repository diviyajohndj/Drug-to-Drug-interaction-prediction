# %% [markdown]
# <a href="https://colab.research.google.com/github/diviyajohndj/Drug-to-Drug-interaction-prediction/blob/main/Copy_of_drug_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import cross_val_score
from sklearn.model_selection  import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import gensim
import spacy
from spacy.symbols import nsubj, VERB
from spacy.symbols import det

nlp = spacy.load('en')

# %%
train_data_f = "train_binary_offsets.csv"
test_data_f = "test_binary_offsets.csv"
df_train = pd.read_csv(train_data_f, low_memory=False)
df_test = pd.read_csv(test_data_f, low_memory=False)

df_train = df_train[df_train['drug1'] != df_train['drug2']]
df_test = df_test[df_test['drug1'] != df_test['drug2']]

# %%
df_train.head()
# Out:
#              sentenceid  ...                                        drugsinsent
# 0  DDI-DrugBank.d519.s3  ...                             Plenaxis,testosterone,
# 1  DDI-DrugBank.d297.s1  ...  MTX,NSAIDs,corticosteroids,TNF blocking agents...
# 2  DDI-DrugBank.d297.s1  ...  MTX,NSAIDs,corticosteroids,TNF blocking agents...
# 3  DDI-DrugBank.d297.s1  ...  MTX,NSAIDs,corticosteroids,TNF blocking agents...
# 4  DDI-DrugBank.d297.s1  ...  MTX,NSAIDs,corticosteroids,TNF blocking agents...
#
# [5 rows x 9 columns]

# %%
print("Length of train dataset: ", df_train.shape)
print("Number of drug paris with no affect on each other: ", df_train.loc[df_train['ddi_label'] == 0].shape)
print("Number of drug pairs that do affect each other: ", df_train.loc[df_train['ddi_label'] == 1].shape)

print("\nLength of test dataset: ", df_test.shape)
print("Number of drug paris with no affect on each other: ", df_test.loc[df_test['ddi_label'] == 0].shape)
print("Number of drug pairs that do affect each other: ", df_test.loc[df_test['ddi_label'] == 1].shape)
# Out:
# Length of train dataset:  (223, 9)
# Number of drug paris with no affect on each other:  (217, 9)
# Number of drug pairs that do affect each other:  (6, 9)
#
# Length of test dataset:  (209, 9)
# Number of drug paris with no affect on each other:  (183, 9)
# Number of drug pairs that do affect each other:  (26, 9)

# %%
def create_train_dev_test(df):
    random_index = np.random.permutation(df.index)
    df_shuffled = df.loc[random_index]
    df_shuffled.reset_index(drop=True, inplace=True)
    rows, columns =  df_shuffled.shape
    train_size = round(rows*.2)
    dev_size   = round(rows*.4)
    df_train = df_shuffled.loc[:train_size]
    df_dev = df_shuffled.loc[train_size:dev_size+train_size].reset_index(drop=True)
    return df_train, df_dev

# df_train.loc[df_train['ddi_label'] == 0].head()
df_train_no_interact, df_dev = create_train_dev_test(df_train.loc[df_train['ddi_label'] == 0])

# %%
frames = [df_train_no_interact, df_train.loc[df_train['ddi_label'] == 1]]
df_train = pd.concat(frames)
df_train.shape
# Out:
# (50, 9)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
triggers = []
with open("triggers.txt") as f:
    for line in f:
        print(line)
        if line!="":
          triggers.append(line)
trigger_words = set(triggers)

negative_words = ['No', 'not', 'neither', 'without', 'lack', 'fail', 
                  'unable', 'abrogate', 'absence', 'prevent', 
                  'unlikely', 'unchanged', 'rarely']

negative_words = set(negative_words)

def tokenize(sentence_df):
    sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    sentences = [sentence for sentence in sentence_df]
    words_in_sents = [nltk.word_tokenize(sent) for sent in sentences]
    return words_in_sents
words_in_sents = tokenize(df_train['sentence_text'])
ddi_embedding_model = gensim.models.Word2Vec(words_in_sents)
ddi_embedding_model.save('ddi.embedding')
new_model = gensim.models.Word2Vec.load('ddi.embedding')
# Out:
# Accident
#
# ACLS
#
# Acute renal failure
#
# Agitation
#
# AKI
#
# Allergic
#
# Allergy
#
# AMS
#
# ARF
#
# Arrest
#
# Bleed
#
# Blood
#
# Bradycardia
#
# Bradicardic
#
# Blocking
#
# C diff
#
# Changes
#
# Code
#
# Coma
#
# Complication
#
# Concern
#
# Condition C
#
# Contrast Nephropathy
#
# Control
#
# d/c
#
# D50
#
# Dc’d
#
# Decrease
#
# Deficiency
#
# Delirium
#
# Desaturation
#
# Diarrhea
#
# Discontinue
#
# DKA
#
# Drop
#
# Drowsy
#
# Drug fever
#
# Drug-induced
#
# Due to
#
# DVT
#
# Effect of
#
# Elevated
#
# Epistaxis
#
# Error
#
# ETOH abuse
#
# FFP
#
# Fluid resuscitation
#
# Glucagon
#
# Hallucinations
#
# Held
#
# Hematoma
#
# Hemoptysis
#
# High INR
#
# HIT
#
# Hives
#
# Hold
#
# Hyperglycemia
#
# Hypernatremia
#
# Hypoglycemia
#
# Hypotension
#
# Hypotensive
#
# Hypoxemia
#
# Hypoxia
#
# Hypoxic
#
# Iatrogenic
#
# Incorrect
#
# Ingestion
#
# Injury
#
# Interaction
#
# Intubate
#
# Intubation
#
# Lethargic
#
# Low
#
# Marijuana
#
# Melena
#
# Mental status
#
# Metabolic acidosis
#
# NAC
#
# Narcan
#
# Non-compliance
#
# Noncompliance
#
# OD
#
# Opiates
#
# Overdose
#
# Overload
#
# Oversedation
#
# Pancytopenia
#
# Polysubstance
#
# Positive
#
# PRBC
#
# Prolonged QTc
#
# Pulmonary Fibrosis
#
# Rash
#
# Rebound
#
# Related
#
# Renal Disease
#
# Renal Failure
#
# Respiratory Distress
#
# Respiratory Failure
#
# Rhadomyolysis
#
# Rise
#
# Rising
#
# SAH
#
# Secondary to
#
# Sedated
#
# Sedating Medications
#
# Seizure
#
# Serotonin Syndrome
#
# Shortness of breath
#
# SOB
#
# Somnolent
#
# Stop
#
# Subtherapeutic
#
# Suicide attempt
#
# Supratherapeutic
#
# SVT
#
# Switch
#
# Tamponade
#
# Temporal
#
# Thrombocytopenia
#
# Toxic
#
# Transfusion
#
# UGIB
#
# Unresponsive
#
# Vit K
#
# Vitamin K
#
# Withdrawal

# %%
def negation_count(x, row):
    """counts total no, not and n't in the sentence """ 
    sent = row['sentence_text']
    count = 0
    for word in nltk.word_tokenize(sent):
        if word == 'not' or word == 'no' or word[-3:] == "n't":
            count += 1
    return count

def negation_count2(x, row):
    """ gives how many negative words in each segment"""
    count = 0
    drug1_i = row['drug1offset'].split('-')
    drug2_i = row['drug2offset'].split('-')
    sentence = row['sentence_text']
    first_phrase = sentence[0:int(drug1_i[0])].split()
    mid_phrase=""
    end_phrase=""
    try:
      mid_phrase = sentence[int(float(drug1_i[-1]))+1:int(drug2_i[0])].split()
      end_phrase = sentence[int(float(drug2_i[-1]))+1:].split()
    except ValueError:
      print("error")
    before_count = len(set(first_phrase) & negative_words)
    middle_count = len(set(mid_phrase) & negative_words)
    end_count = len(set(end_phrase) & negative_words)
    return before_count, middle_count, end_count

def trigger_count(x, row):
    """ total number of trigger words """
    sent = row['sentence_text']
    count = 0
    for word in nltk.word_tokenize(sent.lower()):
        if word in triggers:
            count += 1
    return count

def trigger_count2(x, row):
    ''' counts number of trigger words in each segment '''
    count = 0
    drug1_i = row['drug1offset'].split('-')
    drug2_i = row['drug2offset'].split('-')
    sentence = row['sentence_text']
    first_phrase = sentence[0:int(drug1_i[0])].split()
    mid_phrase=""
    end_phrase=""
    try:

      mid_phrase = sentence[int(float(drug1_i[-1]))+1:int(drug2_i[0])].split()
      end_phrase = sentence[int(float(drug2_i[-1]))+1:].split()
    except ValueError:
      print("error")
    before_count = len(set(first_phrase) & trigger_words)
    middle_count = len(set(mid_phrase) & trigger_words)
    end_count = len(set(end_phrase) & trigger_words)
    return before_count, middle_count, end_count

def ultra_trigger(x, row):
    ''' counts ultra-trigger words '''
    sent = row['sentence_text']
    words = ['coadministration', 'concomitant', 'concomitantly']
    count = 0
    for word in words:
        if word in nltk.word_tokenize(sent.lower()):
            count += 1
    return count
        
def words_sep_by_and(x, row):
    ''' binary feature if drugs are seperated only by and, not used '''
    sent = row['sentence_text']
    d1 = row['drug1']
    d2 = row['drug2']
    sent = sent.replace(d1, 'drug1')
    sent = sent.replace(d2, 'drug2')
    words = nltk.word_tokenize(sent)
    if abs(words.index('drug1') - words.index('drug2')) < 3:
        if words[words.index('drug1') + words.index('drug2')/2] == 'and':
            return 1
    return 0

def key_phrase(x, row):
    ''' binary feature that checks for key phrases, listed below'''
    sent = row['sentence_text']
    d1 = row['drug1']
    d2 = row['drug2']
    sent = sent.replace(d1, 'drug1')
    sent = sent.replace(d2, 'drug2')
    phrases = ['concurrent administration of drug1 and drug2', 'drug1 concurrently with drug2',
            'co-administration of drug1 and drug2', 'coadministration of drug1 and drug2', 
               'concurrent use of drug1 and drug2',]
    for phrase in phrases:
        if phrase in sent.lower():
            return 1
    return 0
    
def num_words_between_drugs(x,row):
    ''' counts number of words between drug mentions '''
    drug1_i = row['drug1offset'].split('-')
    drug2_i = row['drug2offset'].split('-')
    sentence = row['sentence_text']
    pre_phrase=""
    try:
      pre_phrase = sentence[int(float(drug1_i[-1]))+1:int(float(drug2_i[0]))].split()
    except ValueError:
      print("eroor exception")
    return len(pre_phrase)

def num_drugs_between_drugs(x, row):
    ''' counts number of drugs between drug mentions '''
    drug1_i = row['drug1offset'].split('-')
    drug2_i = row['drug2offset'].split('-')
    sentence = row['sentence_text']
    pre_phrase=""
    try:

      pre_phrase = sentence[int(float(drug1_i[-1]))+1:int(float(drug2_i[0]))]
    except ValueError:
      print("error")
    list_of_drugs = row['drugsinsent'].split(",")[0:-1]
    drugs_in_bet = 0
    for drug in list_of_drugs:
        drug_split = drug.split()
        if(pre_phrase.find(drug_split[0]) != -1):
            drugs_in_bet += 1

    return drugs_in_bet

def verb_count(x, row):
    '''counts number of verbs in each segment '''
    pattern = r'''(?x)     
    ([A-Z]\.)+                       # abbrevations
    |\w+'\w+                         # contractions
    | \w+(?:(-|(\.\s))(\n)?\w+)*     # words w/ internal hyphens, extend to next line, and with periods like Mrs. Reed
    '''
    count = 0
    drug1_i = row['drug1offset'].split('-')
    drug2_i = row['drug2offset'].split('-')
    sentence = row['sentence_text']
    first_phrase=""
    mid_phrase=""
    end_phrase=""
    try:
      first_phrase= nltk.pos_tag(nltk.word_tokenize(sentence[0:int(drug1_i[0])]))
      mid_phrase = nltk.pos_tag(nltk.word_tokenize(sentence[int(drug1_i[-1])+1:int(drug2_i[0])]))
      end_phrase = nltk.pos_tag(nltk.word_tokenize(sentence[int(drug2_i[-1])+1:]))
    except ValueError:
      print("error")
    before_count, middle_count, end_count = 0,0,0
    for tag in first_phrase:
        if tag[1].startswith('V'):
            before_count += 1
    for tag in mid_phrase:
        if tag[1].startswith('V'):
            middle_count += 1
    for tag in end_phrase:
        if tag[1].startswith('V'):
            end_count += 1
    return before_count, middle_count, end_count

def dist(idx, enum_list):
    '''helper function for trig_dist '''
    dif = [abs(idx-num) for num,word in enum_list]
    if len(dif) == 0:
        return 0
    else:
        return min(dif)
    
def trig_dist(x, row):
    '''counts distance from both drug mentions to closest trigger'''
    sentence = row['sentence_text']
    sentence = sentence.replace(row['drug1'], 'drug1')
    sentence = sentence.replace(row['drug2'], 'drug2')
    words = nltk.word_tokenize(sentence)
    
    try:
        drug1_i = words.index('drug1')
    except:
        drug1_i = 0
    try:
        drug2_i = words.index('drug2')
    except:
        drug2_i = 0
    enum_words = list(enumerate(words))
    enum_trigs = [(num,word) for num, word in enum_words if word in trigger_words]
    
    return dist(drug1_i, enum_trigs), dist(drug2_i, enum_trigs)

def subj_obj(x, row):
    '''binary feature that checks if drug1 is the nsubj or in its subtree 
    and if drug2 is dobj or in its subtree, returns 1 if both, 0 otherwise'''
    d1, d2 = row['drug1'],row['drug2']
    sent = row['sentence_text'].replace(d1,'drug1').replace(d2,'drug2')
    doc = nlp(sent)
    roots = [r for r in doc if r.head is r and r.pos == VERB] #and r.text in trigger_words]
    d1 = [d for d in doc if d.text == 'drug1']
    d2 = [d for d in doc if d.text == 'drug2']

    flag1 = False
    flag2 = False
    for r in roots:
        subj = [s for s in r.children if s.dep_[:5] == 'nsubj']
        obj = [o for o in r.children if o.dep_[:4] == 'dobj']
        for s in subj:
            if 'drug1' == s.text:
                flag1 = True
            for s1 in s.subtree:
                if s1.text == 'drug1':
                    flag1 = True
        for o in obj:
            if 'drug2' == o.text:
                flag2 = True
            for o1 in o.subtree:
                if o1.text == 'drug2':
                    flag2 = True
    if flag1 and flag2:
        return 1
    else:
        return 0
    
def trig_in_path(x, row):
    ''' binary feature if theres a trigger word in dep path to root '''
    d1, d2 = row['drug1'],row['drug2']
    
    sent = row['sentence_text'].replace(d1,'drug1').replace(d2,'drug2')
    doc = nlp(sent)
    print("doc::::",doc)
    drugs = [d for d in doc if d.text == 'drug1' or d.text == 'drug2']
    print("Printin drus : ",drugs)
    for d in drugs:
        print("for loop for trig_path")
        print("d befoe:",d)
        d = d.head
        print("Printin drus d value after d.head: ",d)
        
        while d.head is not d:
            print("entered while")
            if d.text in trigger_words:
               print("return 1")
               return 1
            else:
                print("change -- d:",d)
                d = d.head
                print("change -- d after:",d)
            if d.head==d :
                return 0
    return 0
    
def both_head(x, row):
    ''' checks if the head of both drug mentions is the same '''
    d1, d2 = row['drug1'],row['drug2']
    sent = row['sentence_text'].replace(d1,'drug1').replace(d2,'drug2')
    doc = nlp(sent)
    #roots = [r for r in doc if r.head is r and r.pos == VERB and r.text in trigger_words]
    drugs = [d for d in doc if d.text == 'drug1' or d.text == 'drug2']
    if  len(drugs) < 2:
        return 0
    if drugs[0].head == drugs[1].head: #and drugs[0].head.pos ==VERB:
        return 1
    return 0

def verb_vect(x, row):
    '''counts number of verbs in each segment '''
    
    sentence = row['sentence_text']
    words = nltk.word_tokenize(sentence)
    pos_words = nltk.pos_tag(words)
    
    try:
        drug1_i = words.index(row['drug1'])
        drug2_i = words.index(row['drug2'])
    except:
        return 0.0, 0.0, 0.0
   
    bef_verb = 0.0
    try:
        for i in range(drug1_i,0, -1):
            if pos_words[i][1].startswith('V') or pos_words[i][1].startswith('N'):
                bef_verb = np.mean(ddi_embedding_model[pos_words[i][0]])
                break
    except:
        bef_verb = 0.0
            
    bet_verb = 0.0
    try:
        for i in range(drug2_i,drug1_i, -1):
            if pos_words[i][1].startswith('V') or pos_words[i][1].startswith('N'):
                bet_verb = np.mean(ddi_embedding_model[pos_words[i][0]])
                break
    except:
        bet_verb = 0.0
            
            
    aft_verb = 0.0   
    try:
        for i in range(drug2_i, len(pos_words)):
            if pos_words[i][1].startswith('V') or pos_words[i][1].startswith('N'):
                aft_verb = np.mean(ddi_embedding_model[pos_words[i][0]])
                break
    except:
        aft_verb = 0.0

    return bef_verb, bet_verb, aft_verb

# %%
def build_features(df):
    c=0
    print("calling build featue:")
    print(c)

    list_of_features = []
    negation_count_l = []
    trigger_count_l = []
    ultra_trigger_l = []
    subj_obj_l = []
    both_head_l = []
    trig_in_path_l = []
    for index, row in df.iterrows():
        negation_count_l.append(negation_count(index,row))
        trigger_count_l.append(trigger_count(index,row))
        ultra_trigger_l.append(ultra_trigger(index,row))
        subj_obj_l.append(subj_obj(index,row))
        both_head_l.append(both_head(index,row))
        trig_in_path_l.append(trig_in_path(index,row))
        print("trig in path loop")
    list_of_features.append(negation_count_l)
    list_of_features.append(trigger_count_l)
    list_of_features.append(ultra_trigger_l)
    list_of_features.append(subj_obj_l)
    list_of_features.append(both_head_l)
    list_of_features.append(trig_in_path_l)

    drugs_between_drugs = []
    words_between_drugs = []
    for index, row in df.iterrows():
        drugs_between_drugs.append(num_drugs_between_drugs(index,row))
        words_between_drugs.append(num_words_between_drugs(index,row))
    list_of_features.append(drugs_between_drugs)
    list_of_features.append(words_between_drugs)
    
    #words_sep_by_and_l = []
    #key_phrase_l = []
    #for index, row in df.iterrows():
        #words_sep_by_and_l.append(words_sep_by_and(index,row))
        #key_phrase_l.append(key_phrase(index,row))
    #list_of_features.append(words_sep_by_and_l)
    #list_of_features.append(key_phrase_l)
    
    btg, betg, atg = [], [], []
    for index, row in df.iterrows():
        before, between, after = trigger_count2(index,row)
        btg.append(before)
        betg.append(between)
        atg.append(after)
    list_of_features.append(btg)
    list_of_features.append(betg)
    list_of_features.append(atg)
    
    n_btg, n_betg, n_atg = [], [], []
    for index, row in df.iterrows():
        before, between, after = negation_count2(index,row)
        n_btg.append(before)
        n_betg.append(between)
        n_atg.append(after)
    list_of_features.append(n_btg)
    list_of_features.append(n_betg)
    list_of_features.append(n_atg)
    
    v_btg, v_betg, v_atg = [], [], []
    for index, row in df.iterrows():
        before, between, after = verb_count(index,row)
        v_btg.append(before)
        v_betg.append(between)
        v_atg.append(after)
    list_of_features.append(v_btg)
    list_of_features.append(v_betg)
    list_of_features.append(v_atg)
    
    word2vec_b, word2vec_bet, word2vec_a = [], [], []
    for index, row in df.iterrows():
        verb_bef, verb_bet, verb_aft = verb_vect(index, row)
        word2vec_b.append(verb_bef)
        word2vec_bet.append(verb_bet)
        word2vec_a.append(verb_aft)
        
    list_of_features.append(word2vec_b)
    list_of_features.append(word2vec_bet)
    list_of_features.append(word2vec_a)

        
    return list_of_features

# %%
vec = TfidfVectorizer(ngram_range=(1, 2), max_df=0.8, max_features=1000)
arr_train_feature_sparse = vec.fit_transform(df_train['sentence_text'])
arr_train_feature = arr_train_feature_sparse.toarray()

arr_test_feature_sparse = vec.transform(df_test["sentence_text"])
arr_test_feature = arr_test_feature_sparse.toarray()

# %%
def convert_to_numpy(list_):
    x = np.asarray(list_)
    y = x.reshape(-1, 1)
    return y

def create_feature_set(mainset,features):
    count=0
    for list_f in features:
        count=count+1
        print("Feature loading:")
        print(count)
        mainset = np.append(mainset, convert_to_numpy(list_f), axis=1)
    return mainset

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
train_feature_list = build_features(df_train)
train_feature_set = create_feature_set(arr_train_feature, train_feature_list)

test_feature_list = build_features(df_test)
test_feature_set = create_feature_set(arr_test_feature, test_feature_list)
# Out:
# calling build featue:
# 0
# doc:::: These medications have included heparin, warfarin, beta-adrenergic receptor blockers, drug1, angiotensin converting enzyme inhibitors, intravenous and oral nitrates, ticlopidine, and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  heparin
# entered while
# change -- d: heparin
# change -- d after: included
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, drug1, gold, hydroxydrug1, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  azathioprine
# entered while
# change -- d: azathioprine
# change -- d after: agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, drug1, chloroquine, gold, hydroxychloroquine, drug2, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, sympathomimetics, drug1, and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  sympathomimetics
# entered while
# change -- d: sympathomimetics
# change -- d after: acid
# entered while
# change -- d: acid
# change -- d after: phenytoin
# entered while
# change -- d: phenytoin
# change -- d after: contraceptives
# entered while
# change -- d: contraceptives
# change -- d after: estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, drug1, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, drug2, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, drug1, oral contraceptives, drug2, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with drug1: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, drug2, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, drug1, nicotinic acid, drug2, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  contraceptives
# entered while
# change -- d: contraceptives
# change -- d after: estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, drug1, calcium channel-blocking drugs, and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  acid
# entered while
# change -- d: acid
# change -- d after: phenytoin
# entered while
# change -- d: phenytoin
# change -- d after: contraceptives
# entered while
# change -- d: contraceptives
# change -- d after: estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, drug1, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, hydroxychloroquine, drug2, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  MTX
# entered while
# change -- d: MTX
# change -- d after: received
# trig in path loop
# doc:::: These drugs include the drug1 and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, drug2, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  include
# entered while
# change -- d: include
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, drug1, azathioprine, chloroquine, drug2, hydroxychloroquine, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: NSAIDs
# entered while
# change -- d: NSAIDs
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: Pharmacokinetic studies indicate that administration of disulfiram or drug1 does not affect the pharmacokinetics of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  disulfiram
# entered while
# change -- d: disulfiram
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: administration
# entered while
# change -- d: administration
# change -- d after: affect
# entered while
# change -- d: affect
# change -- d after: indicate
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with drug1: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, hydroxychloroquine, leflunomide, sulfasalazine, and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: Pharmacokinetic studies indicate that administration of drug1 or drug2 does not affect the pharmacokinetics of acamprosate.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: administration
# entered while
# change -- d: administration
# change -- d after: affect
# entered while
# change -- d: affect
# change -- d after: indicate
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, drug1, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, drug2, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: Heparin, other drug1, drug2, and anti platelet agents are associated with an increase in bleeding.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  agents
# entered while
# change -- d: agents
# change -- d after: associated
# trig in path loop
# doc:::: Other concomitant therapies: In clinical trials, the safety profile in subjects treated with Acamprosate concomitantly with anxiolytics, hypnotics and sedatives (including drug1), or drug2 was similar to that of subjects taking placebo with these concomitant medications.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  including
# entered while
# change -- d: including
# change -- d after: profile
# entered while
# change -- d: profile
# change -- d after: was
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, drug1, drug2, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  acid
# entered while
# change -- d: acid
# change -- d after: phenytoin
# entered while
# change -- d: phenytoin
# change -- d after: contraceptives
# entered while
# change -- d: contraceptives
# change -- d after: estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, drug1, azathioprine, chloroquine, gold, hydroxychloroquine, leflunomide, drug2, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: NSAIDs
# entered while
# change -- d: NSAIDs
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: The pharmacokinetics of drug1 and its major metabolite drug2 were unaffected following co-administration with Acamprosate.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: pharmacokinetics
# entered while
# change -- d: pharmacokinetics
# change -- d after: were
# trig in path loop
# doc:::: Population pharmacokinetic analyses revealed that MTX, drug1, corticosteroids, and drug2 did not influence abatacept clearance.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  MTX
# entered while
# change -- d: MTX
# change -- d after: influence
# entered while
# change -- d: influence
# change -- d after: revealed
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, drug1, chloroquine, gold, drug2, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: drug1, drug2, corticosteroids, TNF blocking agents, azathioprine, chloroquine, gold, hydroxychloroquine, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  received
# entered while
# change -- d: received
# change -- d after: received
# trig in path loop
# doc:::: These medications have included drug1, warfarin, beta-adrenergic receptor blockers, drug2, angiotensin converting enzyme inhibitors, intravenous and oral nitrates, ticlopidine, and aspirin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  included
# entered while
# change -- d: included
# change -- d after: included
# trig in path loop
# doc:::: drug1 (e. g., charcoal) and digestive enzyme preparations containing carbohydrate-splitting enzymes (e. g., amylase, drug2) might reduce the effect of Acarbose and should not be taken concomitantly.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: These medications have included heparin, warfarin, drug1, calcium channel antagonists, drug2, intravenous and oral nitrates, ticlopidine, and aspirin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  warfarin
# entered while
# change -- d: warfarin
# change -- d after: heparin
# entered while
# change -- d: heparin
# change -- d after: included
# trig in path loop
# doc:::: The concomitant intake of drug1 and drug2 does not affect the pharmacokinetics of either drug1 or acamprosate.
# Printin drus :  [drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: intake
# entered while
# change -- d: intake
# change -- d after: affect
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, drug1, gold, hydroxydrug1, drug2, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  azathioprine
# entered while
# change -- d: azathioprine
# change -- d after: agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral drug1, phenytoin, nicotinic acid, sympathomimetics, drug2, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, drug1, chloroquine, drug2, hydroxychloroquine, leflunomide, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: These drugs include the thiazides and other drug1, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, drug2, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, drug1, oral contraceptives, phenytoin, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, drug1, oral contraceptives, phenytoin, drug2, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The concomitant intake of drug1 and Acamprosate does not affect the pharmacokinetics of either drug1 or drug2.
# Printin drus :  [drug1, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: intake
# entered while
# change -- d: intake
# change -- d after: affect
# trig in path loop
# doc:::: These drugs include the thiazides and other drug1, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, nicotinic acid, sympathomimetics, drug2, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These medications have included heparin, drug1, beta-adrenergic receptor blockers, calcium channel antagonists, angiotensin converting enzyme inhibitors, intravenous and oral nitrates, drug2, and aspirin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  heparin
# entered while
# change -- d: heparin
# change -- d after: included
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, drug1, nicotinic acid, sympathomimetics, drug2, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  contraceptives
# entered while
# change -- d: contraceptives
# change -- d after: estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, drug1, estrogens, oral drug2, phenytoin, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, phenothiazines, thyroid products, estrogens, oral drug1, phenytoin, drug2, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  estrogens
# entered while
# change -- d: estrogens
# change -- d after: products
# entered while
# change -- d: products
# change -- d after: phenothiazines
# entered while
# change -- d: phenothiazines
# change -- d after: corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: The majority of patients in RA clinical studies received one or more of the following concomitant medications with ORENCIA: MTX, NSAIDs, corticosteroids, TNF blocking agents, azathioprine, chloroquine, drug1, hydroxychloroquine, drug2, sulfasalazine, and anakinra.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  chloroquine
# entered while
# change -- d: chloroquine
# change -- d after: azathioprine
# entered while
# change -- d: azathioprine
# change -- d after: agents
# entered while
# change -- d: agents
# change -- d after: MTX
# entered while
# change -- d: MTX
# change -- d after: ORENCIA
# entered while
# change -- d: ORENCIA
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: medications
# entered while
# change -- d: medications
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: one
# entered while
# change -- d: one
# change -- d after: received
# trig in path loop
# doc:::: drug1 (e. g., drug2) and digestive enzyme preparations containing carbohydrate-splitting enzymes (e. g., amylase, pancreatin) might reduce the effect of Acarbose and should not be taken concomitantly.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: These drugs include the thiazides and other diuretics, corticosteroids, drug1, thyroid products, estrogens, oral drug2, phenytoin, nicotinic acid, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  corticosteroids
# entered while
# change -- d: corticosteroids
# change -- d after: diuretics
# entered while
# change -- d: diuretics
# change -- d after: thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: These drugs include the thiazides and other drug1, corticosteroids, phenothiazines, thyroid products, estrogens, oral contraceptives, phenytoin, drug2, sympathomimetics, calcium channel-blocking drugs, and isoniazid.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  thiazides
# entered while
# change -- d: thiazides
# change -- d after: include
# trig in path loop
# doc:::: Concurrent administration of a drug1 with drug2 has been associated with an increased risk of serious infections and no significant additional efficacy over use of the drug1s alone.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: administration
# entered while
# change -- d: administration
# change -- d after: associated
# trig in path loop
# doc:::: Concurrent therapy with drug1 and drug2 is not recommended.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  with
# entered while
# change -- d: with
# change -- d after: therapy
# entered while
# change -- d: therapy
# change -- d after: recommended
# trig in path loop
# doc:::: There is insufficient experience to assess the safety and efficacy of drug1 administered concurrently with drug2, and therefore such use is not recommended.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: safety
# entered while
# change -- d: safety
# change -- d after: assess
# entered while
# change -- d: assess
# change -- d after: experience
# entered while
# change -- d: experience
# change -- d after: is
# trig in path loop
# doc:::: Co-administration of drug1 with drug2 produced a 25% increase in AUC and a 33% increase in the Cmax of acamprosate.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: administration
# entered while
# change -- d: administration
# change -- d after: produced
# trig in path loop
# doc:::: Patients taking drug1 concomitantly with drug2 more commonly reported both weight gain and weight loss, compared with patients taking either medication alone.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  taking
# entered while
# change -- d: taking
# change -- d after: taking
# trig in path loop
# doc:::: drug1 (e. g., charcoal) and digestive enzyme preparations containing carbohydrate-splitting enzymes (e. g., amylase, pancreatin) might reduce the effect of drug2 and should not be taken concomitantly.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:278: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:287: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:297: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Feature loading:
# 1
# Feature loading:
# 2
# Feature loading:
# 3
# Feature loading:
# 4
# Feature loading:
# 5
# Feature loading:
# 6
# Feature loading:
# 7
# Feature loading:
# 8
# Feature loading:
# 9
# Feature loading:
# 10
# Feature loading:
# 11
# Feature loading:
# 12
# Feature loading:
# 13
# Feature loading:
# 14
# Feature loading:
# 15
# Feature loading:
# 16
# Feature loading:
# 17
# Feature loading:
# 18
# Feature loading:
# 19
# Feature loading:
# 20
# calling build featue:
# 0
# doc:::: Pharmacokinetic properties of drug1 were not altered by the addition of either drug2 or zidovudine or the combination of drug2 and zidovudine.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: properties
# entered while
# change -- d: properties
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of drug1 were not altered by the addition of either lamivudine or drug2 or the combination of lamivudine and drug2.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: properties
# entered while
# change -- d: properties
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of drug1 were not altered by the addition of either drug2 or zidovudine or the combination of drug2 and zidovudine.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: properties
# entered while
# change -- d: properties
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of drug1 were not altered by the addition of either lamivudine or drug2 or the combination of lamivudine and drug2.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: properties
# entered while
# change -- d: properties
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of abacavir were not altered by the addition of either drug1 or drug2 or the combination of drug1 and drug2.
# Printin drus :  [drug1, drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: addition
# entered while
# change -- d: addition
# change -- d after: by
# entered while
# change -- d: by
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of abacavir were not altered by the addition of either drug1 or drug2 or the combination of drug1 and drug2.
# Printin drus :  [drug1, drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: addition
# entered while
# change -- d: addition
# change -- d after: by
# entered while
# change -- d: by
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of abacavir were not altered by the addition of either drug2 or drug1 or the combination of drug2 and drug1.
# Printin drus :  [drug2, drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: addition
# entered while
# change -- d: addition
# change -- d after: by
# entered while
# change -- d: by
# change -- d after: altered
# trig in path loop
# doc:::: Pharmacokinetic properties of abacavir were not altered by the addition of either drug1 or drug2 or the combination of drug1 and drug2.
# Printin drus :  [drug1, drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: addition
# entered while
# change -- d: addition
# change -- d after: by
# entered while
# change -- d: by
# change -- d after: altered
# trig in path loop
# doc:::: No clinically significant changes to drug1 or drug2 pharmacokinetics were observed following concomitant administration of abacavir.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  pharmacokinetics
# entered while
# change -- d: pharmacokinetics
# change -- d after: to
# entered while
# change -- d: to
# change -- d after: changes
# entered while
# change -- d: changes
# change -- d after: observed
# trig in path loop
# doc:::: No clinically significant changes to drug1 or zidovudine pharmacokinetics were observed following concomitant administration of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  to
# entered while
# change -- d: to
# change -- d after: changes
# entered while
# change -- d: changes
# change -- d after: observed
# trig in path loop
# doc:::: No clinically significant changes to lamivudine or drug1 pharmacokinetics were observed following concomitant administration of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  pharmacokinetics
# entered while
# change -- d: pharmacokinetics
# change -- d after: lamivudine
# entered while
# change -- d: lamivudine
# change -- d after: to
# entered while
# change -- d: to
# change -- d after: changes
# entered while
# change -- d: changes
# change -- d after: observed
# trig in path loop
# doc:::: drug1 has no effect on the pharmacokinetic properties of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  has
# entered while
# change -- d: has
# change -- d after: has
# trig in path loop
# doc:::: drug1 decreases the elimination of drug2 causing an increase in overall exposure . The addition of methadone has no clinically significant effect on the pharmacokinetic properties of drug2.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  decreases
# entered while
# change -- d: decreases
# change -- d after: decreases
# trig in path loop
# doc:::: drug1 decreases the elimination of abacavir causing an increase in overall exposure . The addition of drug2 has no clinically significant effect on the pharmacokinetic properties of abacavir.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  decreases
# entered while
# change -- d: decreases
# change -- d after: decreases
# trig in path loop
# doc:::: drug1 decreases the elimination of drug2 causing an increase in overall exposure . The addition of methadone has no clinically significant effect on the pharmacokinetic properties of drug2.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  decreases
# entered while
# change -- d: decreases
# change -- d after: decreases
# trig in path loop
# doc:::: Ethanol decreases the elimination of drug1 causing an increase in overall exposure . The addition of drug2 has no clinically significant effect on the pharmacokinetic properties of drug1.
# Printin drus :  [drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: elimination
# entered while
# change -- d: elimination
# change -- d after: decreases
# trig in path loop
# doc:::: Ethanol decreases the elimination of drug2 causing an increase in overall exposure . The addition of drug1 has no clinically significant effect on the pharmacokinetic properties of drug2.
# Printin drus :  [drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: elimination
# entered while
# change -- d: elimination
# change -- d after: decreases
# trig in path loop
# doc:::: In a study of 11 HIV-infected patients receiving drug1-maintenance therapy (40 mg and 90 mg daily) with 600 mg of drug2 twice daily (twice the currently recommended dose), oral drug1 clearance increased 22% (90% CI 6% to 42%).
# Printin drus :  [drug2, drug1]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: mg
# entered while
# change -- d: mg
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: study
# entered while
# change -- d: study
# change -- d after: In
# entered while
# change -- d: In
# change -- d after: increased
# trig in path loop
# doc:::: In a study of 11 HIV-infected patients receiving drug2-maintenance therapy (40 mg and 90 mg daily) with 600 mg of drug1 twice daily (twice the currently recommended dose), oral drug2 clearance increased 22% (90% CI 6% to 42%).
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: mg
# entered while
# change -- d: mg
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: study
# entered while
# change -- d: study
# change -- d after: In
# entered while
# change -- d: In
# change -- d after: increased
# trig in path loop
# doc:::: drug1: Concomitant drug2 administration decreased the mean AUC of total ezetimibe approximately 55%.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: Concomitant cholestyramine administration decreased the mean AUC of total drug2 approximately 55%.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: Cholestyramine: Concomitant drug1 administration decreased the mean AUC of total drug2 approximately 55%.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  administration
# entered while
# change -- d: administration
# change -- d after: decreased
# trig in path loop
# doc:::: The incremental LDL-C reduction due to adding drug1 to drug2 might be reduced by this interaction.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  adding
# entered while
# change -- d: adding
# change -- d after: due
# entered while
# change -- d: due
# change -- d after: reduction
# entered while
# change -- d: reduction
# change -- d after: reduced
# trig in path loop
# doc:::: drug1: The safety and effectiveness of drug2 administered with fibrates have not been established.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: The safety and effectiveness of ezetimibe administered with drug2 have not been established.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: Fibrates: The safety and effectiveness of drug1 administered with drug2 have not been established.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: safety
# entered while
# change -- d: safety
# change -- d after: established
# trig in path loop
# doc:::: Co-administration of drug1 with drug2 is not recommended until use in patients is studied.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: administration
# entered while
# change -- d: administration
# change -- d after: recommended
# trig in path loop
# doc:::: drug1: In a pharmacokinetic study, concomitant drug2 administration increased total ezetimibe concentrations approximately 1.5-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increased
# entered while
# change -- d: increased
# change -- d after: increased
# trig in path loop
# doc:::: drug1: In a pharmacokinetic study, concomitant fenofibrate administration increased total drug2 concentrations approximately 1.5-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increased
# entered while
# change -- d: increased
# change -- d after: increased
# trig in path loop
# doc:::: Fenofibrate: In a pharmacokinetic study, concomitant drug1 administration increased total drug2 concentrations approximately 1.5-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  administration
# entered while
# change -- d: administration
# change -- d after: increased
# trig in path loop
# doc:::: drug1: In a pharmacokinetic study, concomitant drug2 administration increased total ezetimibe concentrations approximately 1.7-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increased
# entered while
# change -- d: increased
# change -- d after: increased
# trig in path loop
# doc:::: drug1: In a pharmacokinetic study, concomitant gemfibrozil administration increased total drug2 concentrations approximately 1.7-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increased
# entered while
# change -- d: increased
# change -- d after: increased
# trig in path loop
# doc:::: Gemfibrozil: In a pharmacokinetic study, concomitant drug1 administration increased total drug2 concentrations approximately 1.7-fold.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  administration
# entered while
# change -- d: administration
# change -- d after: increased
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when drug2 was co-administered with atorvastatin, simvastatin, pravastatin, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when ezetimibe was co-administered with drug2, simvastatin, pravastatin, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when ezetimibe was co-administered with atorvastatin, drug2, pravastatin, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when ezetimibe was co-administered with atorvastatin, simvastatin, drug2, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when ezetimibe was co-administered with atorvastatin, simvastatin, pravastatin, drug2, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: No clinically significant pharmacokinetic interactions were seen when ezetimibe was co-administered with atorvastatin, simvastatin, pravastatin, lovastatin, or drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: HMG-CoA reductase inhibitors: No clinically significant pharmacokinetic interactions were seen when drug1 was co-administered with drug2, simvastatin, pravastatin, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  seen
# entered while
# change -- d: seen
# change -- d after: seen
# trig in path loop
# doc:::: HMG-CoA reductase inhibitors: No clinically significant pharmacokinetic interactions were seen when drug1 was co-administered with atorvastatin, drug2, pravastatin, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  seen
# entered while
# change -- d: seen
# change -- d after: seen
# trig in path loop
# doc:::: HMG-CoA reductase inhibitors: No clinically significant pharmacokinetic interactions were seen when drug1 was co-administered with atorvastatin, simvastatin, drug2, lovastatin, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  seen
# entered while
# change -- d: seen
# change -- d after: seen
# trig in path loop
# doc:::: HMG-CoA reductase inhibitors: No clinically significant pharmacokinetic interactions were seen when drug1 was co-administered with atorvastatin, simvastatin, pravastatin, drug2, or fluvastatin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  seen
# entered while
# change -- d: seen
# change -- d after: seen
# trig in path loop
# doc:::: HMG-CoA reductase inhibitors: No clinically significant pharmacokinetic interactions were seen when drug1 was co-administered with atorvastatin, simvastatin, pravastatin, lovastatin, or drug2.
# ...
# doc:::: DIFLUCAN reduces the metabolism of drug1, drug2, and glipizide and increases the plasma concentration of these agents.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: metabolism
# entered while
# change -- d: metabolism
# change -- d after: reduces
# trig in path loop
# doc:::: DIFLUCAN reduces the metabolism of drug1, glyburide, and drug2 and increases the plasma concentration of these agents.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: metabolism
# entered while
# change -- d: metabolism
# change -- d after: reduces
# trig in path loop
# doc:::: DIFLUCAN reduces the metabolism of tolbutamide, drug1, and drug2 and increases the plasma concentration of these agents.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  tolbutamide
# entered while
# change -- d: tolbutamide
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: metabolism
# entered while
# change -- d: metabolism
# change -- d after: reduces
# trig in path loop
# doc:::: When drug1 is used concomitantly with these or other drug2, blood glucose concentrations should be carefully monitored and the dose of the sulfonylurea should be adjusted as necessary.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  used
# entered while
# change -- d: used
# change -- d after: used
# trig in path loop
# doc:::: When drug1 is used concomitantly with these or other drug2 oral hypoglycemic agents, blood glucose concentrations should be carefully monitored and the dose of the drug2 should be adjusted as necessary.
# Printin drus :  [drug1, drug2, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  used
# entered while
# change -- d: used
# change -- d after: monitored
# trig in path loop
# doc:::: When DIFLUCAN is used concomitantly with these or other drug1, blood glucose concentrations should be carefully monitored and the dose of the drug2 should be adjusted as necessary.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  these
# entered while
# change -- d: these
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: used
# entered while
# change -- d: used
# change -- d after: monitored
# trig in path loop
# doc:::: drug1: Prothrombin time might be increased in patients receiving concomitant drug2 and coumarin-type anticoagulants.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: Prothrombin time might be increased in patients receiving concomitant DIFLUCAN and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: Coumarin-type anticoagulants: Prothrombin time might be increased in patients receiving concomitant drug1 and drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: in
# entered while
# change -- d: in
# change -- d after: increased
# trig in path loop
# doc:::: In post-marketing experience, as with other drug1, bleeding events (bruising, epistaxis, gastrointestinal bleeding, hematuria, and melena) have been reported in association with increases in prothrombin time in patients receiving drug2 concurrently with warfarin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  with
# entered while
# change -- d: with
# change -- d after: as
# entered while
# change -- d: as
# change -- d after: reported
# trig in path loop
# doc:::: In post-marketing experience, as with other drug1, bleeding events (bruising, epistaxis, gastrointestinal bleeding, hematuria, and melena) have been reported in association with increases in prothrombin time in patients receiving fluconazole concurrently with drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  with
# entered while
# change -- d: with
# change -- d after: as
# entered while
# change -- d: as
# change -- d after: reported
# trig in path loop
# doc:::: In post-marketing experience, as with other azole antifungals, bleeding events (bruising, epistaxis, gastrointestinal bleeding, hematuria, and melena) have been reported in association with increases in prothrombin time in patients receiving drug1 concurrently with drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: in
# entered while
# change -- d: in
# change -- d after: increases
# entered while
# change -- d: increases
# change -- d after: with
# entered while
# change -- d: with
# change -- d after: association
# entered while
# change -- d: association
# change -- d after: in
# entered while
# change -- d: in
# change -- d after: reported
# trig in path loop
# doc:::: Careful monitoring of prothrombin time in patients receiving drug1 and drug2 is recommended.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: in
# entered while
# change -- d: in
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: drug1: drug2 increases the plasma concentrations of phenytoin.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: drug1: DIFLUCAN increases the plasma concentrations of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: Phenytoin: drug1 increases the plasma concentrations of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: Careful monitoring of drug1 concentrations in patients receiving drug2 and drug1 is recommended.
# Printin drus :  [drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: Careful monitoring of drug2 concentrations in patients receiving drug1 and drug2 is recommended.
# Printin drus :  [drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: drug1: drug2 might significantly increase cyclosporine levels in renal transplant patients with or without renal impairment.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: DIFLUCAN might significantly increase drug2 levels in renal transplant patients with or without renal impairment.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increase
# entered while
# change -- d: increase
# change -- d after: increase
# trig in path loop
# doc:::: Cyclosporine: drug1 might significantly increase drug2 levels in renal transplant patients with or without renal impairment.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  Cyclosporine
# entered while
# change -- d: Cyclosporine
# change -- d after: increase
# trig in path loop
# doc:::: Careful monitoring of drug1 concentrations and serum creatinine is recommended in patients receiving drug2 and drug1.
# Printin drus :  [drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: Careful monitoring of drug2 concentrations and serum creatinine is recommended in patients receiving drug1 and drug2.
# Printin drus :  [drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: drug1: drug1 enhances the metabolism of concurrently administered drug2.
# Printin drus :  [drug1, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: drug1: drug1 enhances the metabolism of concurrently administered drug2.
# Printin drus :  [drug1, drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  drug1
# entered while
# change -- d: drug1
# change -- d after: drug1
# trig in path loop
# doc:::: Depending on clinical circumstances, consideration should be given to increasing the dose of drug1 when it is administered with drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: dose
# entered while
# change -- d: dose
# change -- d after: increasing
# entered while
# change -- d: increasing
# change -- d after: to
# entered while
# change -- d: to
# change -- d after: given
# trig in path loop
# doc:::: drug1: drug2 increases the serum concentrations of theophylline.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: drug1: DIFLUCAN increases the serum concentrations of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: Theophylline: drug1 increases the serum concentrations of drug2.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  increases
# entered while
# change -- d: increases
# change -- d after: increases
# trig in path loop
# doc:::: Careful monitoring of serum drug1 concentrations in patients receiving drug2 and drug1 is recommended.
# Printin drus :  [drug1, drug2, drug1]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: Careful monitoring of serum drug2 concentrations in patients receiving drug1 and drug2 is recommended.
# Printin drus :  [drug2, drug1, drug2]
# for loop for trig_path
# d befoe: drug2
# Printin drus d value after d.head:  concentrations
# entered while
# change -- d: concentrations
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: monitoring
# entered while
# change -- d: monitoring
# change -- d after: recommended
# trig in path loop
# doc:::: drug1: Because of the occurrence of serious cardiac dysrhythmias secondary to prolongation of the QTc interval in patients receiving drug2 in conjunction with terfenadine, interaction studies have been performed.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  performed
# entered while
# change -- d: performed
# change -- d after: performed
# trig in path loop
# doc:::: drug1: Because of the occurrence of serious cardiac dysrhythmias secondary to prolongation of the QTc interval in patients receiving azole antifungals in conjunction with drug2, interaction studies have been performed.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  performed
# entered while
# change -- d: performed
# change -- d after: performed
# trig in path loop
# doc:::: Terfenadine: Because of the occurrence of serious cardiac dysrhythmias secondary to prolongation of the QTc interval in patients receiving drug1 in conjunction with drug2, interaction studies have been performed.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  receiving
# entered while
# change -- d: receiving
# change -- d after: patients
# entered while
# change -- d: patients
# change -- d after: in
# entered while
# change -- d: in
# change -- d after: interval
# entered while
# change -- d: interval
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: prolongation
# entered while
# change -- d: prolongation
# change -- d after: to
# entered while
# change -- d: to
# change -- d after: secondary
# entered while
# change -- d: secondary
# change -- d after: dysrhythmias
# entered while
# change -- d: dysrhythmias
# change -- d after: of
# entered while
# change -- d: of
# change -- d after: occurrence
# entered while
# change -- d: occurrence
# change -- d after: Because
# entered while
# change -- d: Because
# change -- d after: performed
# trig in path loop
# doc:::: Another study at a 400-mg and 800-mg daily dose of drug1 demonstrated that drug2 taken in doses of 400 mg per day or greater significantly increases plasma levels of terfenadine when taken concomitantly.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: dose
# entered while
# change -- d: dose
# change -- d after: at
# entered while
# change -- d: at
# change -- d after: study
# entered while
# change -- d: study
# change -- d after: demonstrated
# trig in path loop
# doc:::: Another study at a 400-mg and 800-mg daily dose of drug1 demonstrated that DIFLUCAN taken in doses of 400 mg per day or greater significantly increases plasma levels of drug2 when taken concomitantly.
# Printin drus :  [drug1, drug2]
# for loop for trig_path
# d befoe: drug1
# Printin drus d value after d.head:  of
# entered while
# change -- d: of
# change -- d after: dose
# entered while
# change -- d: dose
# change -- d after: at
# entered while
# change -- d: at
# change -- d after: study
# entered while
# change -- d: study
# change -- d after: demonstrated
# trig in path loop
# error
# eroor exception
# error
# eroor exception
# error
# eroor exception
# error
# eroor exception
# error
# eroor exception
# error
# eroor exception
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# Feature loading:
# 1
# Feature loading:
# 2
# Feature loading:
# 3
# Feature loading:
# 4
# Feature loading:
# 5
# Feature loading:
# 6
# Feature loading:
# 7
# Feature loading:
# 8
# Feature loading:
# 9
# Feature loading:
# 10
# Feature loading:
# 11
# Feature loading:
# 12
# Feature loading:
# 13
# Feature loading:
# 14
# Feature loading:
# 15
# Feature loading:
# 16
# Feature loading:
# 17
# Feature loading:
# 18
# Feature loading:
# 19
# Feature loading:
# 20

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score
mn = MultinomialNB()
print("Baseline with only vectorized bag of words:")

print("starting to fit")
mn_model = mn.fit(arr_train_feature, df_train.ddi_label)

print("starting to predict")
pred_test = mn_model.predict(arr_test_feature)

print('accuracy: ', accuracy_score(df_test.ddi_label, pred_test))
print(f1_score(df_test.ddi_label, pred_test, average=None, pos_label = 1))
# Out:
# Baseline with only vectorized bag of words:
# starting to fit
# starting to predict
# accuracy:  0.8755980861244019
# [0.93367347 0.        ]

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV

def run_model(model):
    print("starting to fit")
    fit_model = model.fit(train_feature_set, df_train.ddi_label)
    print("starting to predict")
    pred_test = fit_model.predict(test_feature_set)
    print('accuracy: ', accuracy_score(df_test.ddi_label, pred_test))
    print(f1_score(df_test.ddi_label, pred_test, average=None, pos_label = 1))
    
def gridsearch(model, parameters):
    clf = GridSearchCV(model, parameters)
    clf.fit(train_feature_set, df_train.ddi_label)
    clf_pred_test = clf.predict(test_feature_set)
    print('accuracy: ', accuracy_score(df_test.ddi_label, clf_pred_test))
    print(f1_score(df_test.ddi_label, clf_pred_test, average=None, pos_label = 1))

# %%
knn = KNeighborsClassifier(n_neighbors=3)
run_model(knn)
# Out:
# starting to fit
# starting to predict
# accuracy:  0.8708133971291866
# [0.93094629 0.        ]
